# %%
numara=20
def carpma(num):
  numara=10
  return numara*num

# %%
carpma(5)
# Out:
# 50

# %%
print(numara)
# Out:
# 20

# %% [markdown]
# local, enclosing, global, built-in

# %%
benimadim="Sabri"
def fonksiyonum():
  benimadim="kadri"
  def icfonksiyon():
    benimadim="kilic"
  icfonksiyon()

# %%
fonksiyonum()

# %%
benimadim
# Out:
# 'Sabri'

# %%
y= 10
def yenifonksiyon(y):
  print(y)
  y=5
  print(y)
  return y

# %%
yenifonksiyon(40)
# Out:
# 40
# 5
# 5

# %%
y
# Out:
# 10

# %%
y=yenifonksiyon(10)
# Out:
# 10
# 5

# %%
y
# Out:
# 5

# %%
y=10
def ornekfonksiyon():
  global y
  y=5
  print(y)

# %%
y
# Out:
# 10

# %%
ornekfonksiyon()
# Out:
# 5

# %%
def toplama(a,b):
  return a+b
def cikarma(a,b):
  return a-b
def carpma(a,b):
  return a*b
def bolme(a,b):
  return a/b
a=int(input("ilk sayiyi girin:"))
b=int(input("ikinci sayiyi girin:"))
islem=input("islemi girin:")
if islem == "toplama":
  print(toplama(a,b))
if islem == "cikarma":
  print(cikarma(a,b))
if islem == "carpma":
  print(carpma(a,b))
if islem == "bolme":
  print(bolme(a,b))
# Out:
# ilk sayiyi girin:9
# ikinci sayiyi girin:9
# islemi girin:carpma
# 81
