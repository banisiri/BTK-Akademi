# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame=pd.read_csv("audi.csv")
dataFrame.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10668.000000   10668.000000   10668.000000  10668.000000  10668.000000
# mean    2017.100675   22896.685039   24827.244001    126.011436     50.770022
# std        2.167494   11714.841888   23505.257205     67.170294     12.949782
# min     1997.000000    1490.000000       1.000000      0.000000     18.900000
# 25%     2016.000000   15130.750000    5968.750000    125.000000     40.900000
# 50%     2017.000000   20200.000000   19000.000000    145.000000     49.600000
# 75%     2019.000000   27990.000000   36464.500000    145.000000     58.900000
# max     2020.000000  145000.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10668.000000
# mean       1.930709
# std        0.602957
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
dataFrame.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sbn.displot(dataFrame["price"])

# %%
sbn.countplot(dataFrame["year"])
# Out:
# c:\Users\90507\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
dataFrame.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.592581 -0.789667  0.093066 -0.351281   -0.031582
# price       0.592581  1.000000 -0.535357  0.356157 -0.600334    0.591262
# mileage    -0.789667 -0.535357  1.000000 -0.166547  0.395103    0.070710
# tax         0.093066  0.356157 -0.166547  1.000000 -0.635909    0.393075
# mpg        -0.351281 -0.600334  0.395103 -0.635909  1.000000   -0.365621
# engineSize -0.031582  0.591262  0.070710  0.393075 -0.365621    1.000000

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# mpg          -0.600334
# mileage      -0.535357
# tax           0.356157
# engineSize    0.591262
# year          0.592581
# price         1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(x="mileage",y="price",data=dataFrame)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price",ascending=False).head(20)
# Out:
#       model  year   price transmission  mileage fuelType  tax   mpg  \
# 4783     R8  2020  145000    Semi-Auto     2000   Petrol  145  21.1
# 2255     R8  2020  137995    Semi-Auto       70   Petrol  145  21.1
# 4179     R8  2019  137500    Semi-Auto       10   Petrol  150  21.4
# 3367     R8  2019  135000    Automatic     1000   Petrol  145  32.8
# 5459     R8  2020  133900    Semi-Auto      333   Petrol  145  21.4
# 1646     R8  2019  129000    Semi-Auto     4000   Petrol  145  21.4
# 10468    R8  2019  125000    Automatic    13663   Petrol  150  21.4
# 4925     R8  2019  125000    Semi-Auto      500   Petrol  145  21.4
# 3359     R8  2019  125000    Automatic      100   Petrol  145  24.1
# 7445     R8  2019  119995    Semi-Auto     7800   Petrol  145  21.4
# 7128     R8  2019  119450    Automatic     3000   Petrol  145  21.4
# 4742     R8  2019  117990    Automatic    11936   Petrol  145  21.4
# 5707     R8  2019  116000    Automatic     2369   Petrol  145  22.6
# ...

# %%
dataFrame.sort_values("price", ascending=True).head(20)
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 10588    A3  2003   1490    Automatic   101000   Diesel  240  44.5         1.9
# 10552    A4  2004   1699       Manual   110000   Diesel  315  36.2         2.5
# 7795     A3  2005   1975       Manual   104000   Petrol  240  38.1         2.0
# 10108    TT  2002   1990       Manual   131925   Petrol  325  30.1         1.8
# 7404     A3  2009   2490       Manual   152034   Diesel  150  55.4         1.9
# 9822     A6  2008   2490       Manual   323000   Diesel  200  44.1         2.0
# 10158    A2  2003   2490       Manual   100000   Diesel   30  65.7         1.4
# 9897     A3  2005   2495       Manual   122000   Diesel  150  53.3         0.0
# 9359     A6  2003   2495       Manual   129000   Diesel  325  31.7         2.5
# 7750     A6  2003   2495    Automatic   117000   Diesel  290  39.8         2.5
# 10259    A6  2007   2600       Manual   127700   Diesel  205  44.1         2.0
# ...

# %%
len(dataFrame)
# Out:
# 10668

# %%
len(dataFrame)*0.01
# Out:
# 106.68

# %%
doksandokuzDataf=dataFrame.sort_values("price", ascending=False).iloc[131:]

# %%
doksandokuzDataf.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  10537.000000  10537.000000   10537.000000  10537.000000  10537.000000
# mean    2017.075733  22242.956819   25053.583847    125.642498     51.021980
# std        2.166467   9925.584942   23550.811278     67.126593     12.819455
# min     1997.000000   1490.000000       5.000000      0.000000     18.900000
# 25%     2016.000000  15000.000000    6000.000000    125.000000     40.900000
# 50%     2017.000000  20000.000000   19349.000000    145.000000     49.600000
# 75%     2019.000000  27637.000000   36790.000000    145.000000     58.900000
# max     2020.000000  58495.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10537.000000
# mean       1.909291
# std        0.567867
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
sbn.displot(doksandokuzDataf["price"])

# %%
sbn.displot(dataFrame["price"])

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1997     4650.000000
# 1998     4999.000000
# 2002     2433.000000
# 2003     3408.333333
# 2004     5053.600000
# 2005     3490.714286
# 2006     6499.111111
# 2007     7325.250000
# 2008     6281.428571
# 2009     6281.956522
# 2010     7224.093750
# 2011     8944.808511
# 2012     9860.811765
# 2013    11690.790378
# 2014    13890.659955
# 2015    15128.235235
# 2016    16908.725051
# 2017    19951.624289
# 2018    26296.707176
# 2019    30410.752268
# 2020    35967.067039
# Name: price, dtype: float64

# %%
doksandokuzDataf.groupby("year").mean()["price"]
# Out:
# year
# 1997     4650.000000
# 1998     4999.000000
# 2002     2433.000000
# 2003     3408.333333
# 2004     5053.600000
# 2005     3490.714286
# 2006     6499.111111
# 2007     7325.250000
# 2008     6281.428571
# 2009     6281.956522
# 2010     7224.093750
# 2011     8944.808511
# 2012     9860.811765
# 2013    11690.790378
# 2014    13787.298206
# 2015    15128.235235
# 2016    16847.266055
# 2017    19867.091144
# 2018    25344.289941
# 2019    29585.353372
# 2020    32881.481928
# Name: price, dtype: float64

# %%
dataFrame[dataFrame.year != 1997].groupby("year").mean()["price"]
# Out:
# year
# 1998     4999.000000
# 2002     2433.000000
# 2003     3408.333333
# 2004     5053.600000
# 2005     3490.714286
# 2006     6499.111111
# 2007     7325.250000
# 2008     6281.428571
# 2009     6281.956522
# 2010     7224.093750
# 2011     8944.808511
# 2012     9860.811765
# 2013    11690.790378
# 2014    13890.659955
# 2015    15128.235235
# 2016    16908.725051
# 2017    19951.624289
# 2018    26296.707176
# 2019    30410.752268
# 2020    35967.067039
# Name: price, dtype: float64

# %%
dataFrame[dataFrame.year != 1998].groupby("year").mean()["price"]
# Out:
# year
# 1997     4650.000000
# 2002     2433.000000
# 2003     3408.333333
# 2004     5053.600000
# 2005     3490.714286
# 2006     6499.111111
# 2007     7325.250000
# 2008     6281.428571
# 2009     6281.956522
# 2010     7224.093750
# 2011     8944.808511
# 2012     9860.811765
# 2013    11690.790378
# 2014    13890.659955
# 2015    15128.235235
# 2016    16908.725051
# 2017    19951.624289
# 2018    26296.707176
# 2019    30410.752268
# 2020    35967.067039
# Name: price, dtype: float64

# %%
dataFrame=doksandokuzDataf

# %%
dataFrame
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 2254     Q5  2020  58495    Semi-Auto     4000   Diesel  145  32.5         3.0
# 6254     Q8  2019  58450    Semi-Auto     8450   Diesel  145  33.6         3.0
# 6606     Q8  2019  58450    Automatic     7000   Diesel  145  33.6         3.0
# 7689     R8  2014  58450    Automatic    35000   Petrol  570  21.9         5.2
# 4734     Q7  2019  58216    Automatic     3052   Diesel  145  33.2         3.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 7404     A3  2009   2490       Manual   152034   Diesel  150  55.4         1.9
# 10108    TT  2002   1990       Manual   131925   Petrol  325  30.1         1.8
# 7795     A3  2005   1975       Manual   104000   Petrol  240  38.1         2.0
# 10552    A4  2004   1699       Manual   110000   Diesel  315  36.2         2.5
# 10588    A3  2003   1490    Automatic   101000   Diesel  240  44.5         1.9
#
# ...

# %%
sbn.displot(dataFrame["price"])

# %%
dataframe=dataFrame[dataFrame.year != 1997]

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1997     4650.000000
# 1998     4999.000000
# 2002     2433.000000
# 2003     3408.333333
# 2004     5053.600000
# 2005     3490.714286
# 2006     6499.111111
# 2007     7325.250000
# 2008     6281.428571
# 2009     6281.956522
# 2010     7224.093750
# 2011     8944.808511
# 2012     9860.811765
# 2013    11690.790378
# 2014    13787.298206
# 2015    15128.235235
# 2016    16847.266055
# 2017    19867.091144
# 2018    25344.289941
# 2019    29585.353372
# 2020    32881.481928
# Name: price, dtype: float64

# %%
dataFrame.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 2254    Q5  2020  58495    Semi-Auto     4000   Diesel  145  32.5         3.0
# 6254    Q8  2019  58450    Semi-Auto     8450   Diesel  145  33.6         3.0
# 6606    Q8  2019  58450    Automatic     7000   Diesel  145  33.6         3.0
# 7689    R8  2014  58450    Automatic    35000   Petrol  570  21.9         5.2
# 4734    Q7  2019  58216    Automatic     3052   Diesel  145  33.2         3.0

# %%
dataFrame=dataFrame.drop("transmission",axis=1)

# %%
dataFrame.head()
# Out:
#      model  year  price  mileage fuelType  tax   mpg  engineSize
# 2254    Q5  2020  58495     4000   Diesel  145  32.5         3.0
# 6254    Q8  2019  58450     8450   Diesel  145  33.6         3.0
# 6606    Q8  2019  58450     7000   Diesel  145  33.6         3.0
# 7689    R8  2014  58450    35000   Petrol  570  21.9         5.2
# 4734    Q7  2019  58216     3052   Diesel  145  33.2         3.0

# %%
y=dataFrame["price"].values
x=dataFrame.drop("price",axis=1).values

# %%
x,y
# Out:
# (array([[' Q5', 2020, 4000, ..., 145, 32.5, 3.0],
#         [' Q8', 2019, 8450, ..., 145, 33.6, 3.0],
#         [' Q8', 2019, 7000, ..., 145, 33.6, 3.0],
#         ...,
#         [' A3', 2005, 104000, ..., 240, 38.1, 2.0],
#         [' A4', 2004, 110000, ..., 315, 36.2, 2.5],
#         [' A3', 2003, 101000, ..., 240, 44.5, 1.9]], dtype=object),
#  array([58495, 58450, 58450, ...,  1975,  1699,  1490], dtype=int64))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.3,random_state=10)

# %%
len(x_train),len(y_train)
# Out:
# (7375, 7375)
